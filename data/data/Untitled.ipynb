# %%
# pip install llama_index

# %%
from fastapi import FastAPI
from pydantic import BaseModel
import uvicorn
from fastapi.responses import FileResponse, HTMLResponse, JSONResponse, PlainTextResponse
import os
from llama_index.llms import OpenAI
from qdrant_client import QdrantClient
from langchain.llms import OpenAI
from langchain.vectorstores import Qdrant
from langchain.embeddings.openai import OpenAIEmbeddings
import os
from langchain.chains import  ConversationalRetrievalChain
os.environ['OPENAI_API_KEY']='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'
qdrant_client = QdrantClient(
    url="https://28ec6cf8-45bd-4668-a4dc-8096d307f387.us-east4-0.gcp.cloud.qdrant.io:6333",
    api_key="YfRRnOObjGFKU9DTWMZFoPPWinh5v_jgyuvTIUffsto9nyMoAZwzHQ",
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [4], in <module>
#       4 from fastapi.responses import FileResponse, HTMLResponse, JSONResponse, PlainTextResponse
#       5 import os
# ----> 6 from llama_index.llms import OpenAI
#       7 from qdrant_client import QdrantClient
#       8 from langchain.llms import OpenAI
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\llama_index\__init__.py:14, in <module>
#      12 # import global eval handler
#      13 from llama_index.callbacks.global_handlers import set_global_handler
# ---> 14 from llama_index.data_structs.struct_type import IndexStructType
#      16 # embeddings
#      17 from llama_index.embeddings.langchain import LangchainEmbedding
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\llama_index\data_structs\__init__.py:3, in <module>
#       1 """Init file."""
# ...

# %%
def get_vector_store():
    embeddings = OpenAIEmbeddings()
    vector_store = Qdrant(
        client=qdrant_client,
        collection_name="Data",
        embeddings=embeddings,
    )
    return vector_store
store = get_vector_store()
qa = ConversationalRetrievalChain.from_llm(
            llm=OpenAI(),
            chain_type="stuff",
            retriever=store.as_retriever(search_type="similarity"),
            return_source_documents=True,
            return_generated_question=True,
        )
def run(query,chat_history):
    result  = qa({"question": query, "chat_history":chat_history})
    return result['answer']
run("HI",[])
